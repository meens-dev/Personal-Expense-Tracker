# %%
import csv
from datetime import datetime

expenses = []
monthly_budget = 0

# Load expenses from file at the start
def load_expenses():
    global expenses
    try:
        with open('expenses.csv', mode='r') as file:
            reader = csv.DictReader(file)
            expenses = [row for row in reader]
            for exp in expenses:
                exp['amount'] = float(exp['amount'])  # Convert string to float
    except FileNotFoundError:
        expenses = []

# Save expenses to file
def save_expenses():
    with open('expenses.csv', mode='w', newline='') as file:
        fieldnames = ['date', 'category', 'amount', 'description']
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        for exp in expenses:
            writer.writerow(exp)

# Add a new expense
def add_expense():
    date = input("Enter date (YYYY-MM-DD): ")
    category = input("Enter category (e.g., Food, Travel): ")
    amount = float(input("Enter amount spent: "))
    description = input("Enter a brief description: ")

    expense = {
        'date': date,
        'category': category,
        'amount': amount,
        'description': description
    }

    expenses.append(expense)
    print("Expense added successfully!\n")

# View all expenses
def view_expenses():
    if not expenses:
        print("No expenses recorded.")
        return

    for exp in expenses:
        print(f"{exp['date']} | {exp['category']} | ₹{exp['amount']} | {exp['description']}")

# Set and track budget
def track_budget():
    global monthly_budget
    if monthly_budget == 0:
        monthly_budget = float(input("Set your monthly budget: "))

    total_spent = sum(exp['amount'] for exp in expenses)
    balance = monthly_budget - total_spent

    print(f"Total spent: ₹{total_spent}")
    if balance < 0:
        print(f"⚠️ You have exceeded your budget by ₹{abs(balance)}!")
    else:
        print(f"✅ You have ₹{balance} remaining this month.")

# Menu system
def show_menu():
    load_expenses()
    while True:
        print("\n📌 Personal Expense Tracker Menu:")
        print("1. Add Expense")
        print("2. View Expenses")
        print("3. Track Budget")
        print("4. Save Expenses")
        print("5. Exit")
        choice = input("Choose an option (1–5): ")

        if choice == '1':
            add_expense()
        elif choice == '2':
            view_expenses()
        elif choice == '3':
            track_budget()
        elif choice == '4':
            save_expenses()
            print("Expenses saved.")
        elif choice == '5':
            save_expenses()
            print("Goodbye!")
            break
        else:
            print("Invalid option. Try again.")

# Run the program
show_menu()
# Out:
# 📌 Personal Expense Tracker Menu:
# 1. Add Expense
# 2. View Expenses
# 3. Track Budget
# 4. Save Expenses
# 5. Exit
# Choose an option (1–5): 1
# Enter date (YYYY-MM-DD): 2025-03-28
# Enter category (e.g., Food, Travel): food
# Enter amount spent: 2000
# Enter a brief description: kalsang
# Expense added successfully!
#
#
# 📌 Personal Expense Tracker Menu:
# 1. Add Expense
# 2. View Expenses
# 3. Track Budget
# 4. Save Expenses
# 5. Exit
# Choose an option (1–5): 3
# Set your monthly budget: 20000
# Total spent: ₹2000.0
# ✅ You have ₹18000.0 remaining this month.
#
# 📌 Personal Expense Tracker Menu:
# 1. Add Expense
# 2. View Expenses
# 3. Track Budget
# 4. Save Expenses
# 5. Exit
# Choose an option (1–5): 3
# Total spent: ₹2000.0
# ✅ You have ₹18000.0 remaining this month.
#
# 📌 Personal Expense Tracker Menu:
# 1. Add Expense
# 2. View Expenses
# 3. Track Budget
# 4. Save Expenses
# 5. Exit
# Choose an option (1–5): 4
# Expenses saved.
#
# 📌 Personal Expense Tracker Menu:
# ...

# %%
import pandas as pd

# Load and display the CSV file
df = pd.read_csv('expenses.csv')
df
# Out:
#          date category  amount description
# 0  2025-03-28     food  2000.0     kalsang
